# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\muhta\\Downloads\\HealthAnalytics', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\python38.zip', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\DLLs', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code', '', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages\\win32', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages\\win32\\lib', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages\\Pythonwin']

# %%
sys.path.append(r"C:\Users\muhta\Downloads\HealthAnalytics")
print(sys.path)
# Out:
# ['c:\\Users\\muhta\\Downloads\\HealthAnalytics', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\python38.zip', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\DLLs', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code', '', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages\\win32', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages\\win32\\lib', 'c:\\Users\\muhta\\anaconda3\\envs\\hds_code\\lib\\site-packages\\Pythonwin', 'C:\\Users\\muhta\\Downloads\\HealthAnalytics']

# %%
# !pip install C:/Users/muhta/Downloads/HealthAnalytics
# Out:
# Processing c:\users\muhta\downloads\healthanalytics
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for HealthAnalytics: filename=HealthAnalytics-0.1-py3-none-any.whl size=1691 sha256=2b7401bb1fa4f8502b6ce4c6d31d010370600b5e1e1d09bc7a8e69f8c030f611
#   Stored in directory: C:\Users\muhta\AppData\Local\Temp\pip-ephem-wheel-cache-96zjprxo\wheels\f3\2f\56\44c67e9adffd2e5538895d8ee01d79046f2d9be7010ea33355
# Successfully built HealthAnalytics
# ...
#   Attempting uninstall: HealthAnalytics
#     Found existing installation: HealthAnalytics 0.1
#     Uninstalling HealthAnalytics-0.1:
#       Successfully uninstalled HealthAnalytics-0.1
# ...

# %%
import advanced_clustering

# %%
import utils
import heatmap
import deep_learning_predictive_modeling
import interactive
import preprocessing
import mystatistics
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\muhta\anaconda3\envs\hds_code\lib\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 2
#     import heatmap
#
#   File c:\Users\muhta\Downloads\HealthAnalytics\heatmap.py:37
#     def generate_vaccine_based_heat_map(data, geo_data=world, location_column, vaccines_supplied_column, vaccines_required_column, title='Vaccine Based Heat Map'):
#                                         ^
# SyntaxError: non-default argument follows default argument

# %%
import pandas as pd

# %%
path = "C:/Users/muhta/Downloads/influenza_weekly.csv"

df=utils.load_data(file_path=path)
# Out:
# c:\Users\muhta\Downloads\HealthAnalytics\utils.py:15: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
df=preprocessing.handle_missing_values(df)

# %%
df.head()
# Out:
#      REPORT_ID    Country                      WHOREGION  \
# 849       8627  Argentina  Region of the Americas of WHO
# 850       8628  Argentina  Region of the Americas of WHO
# 851       8629  Argentina  Region of the Americas of WHO
# 852       8630  Argentina  Region of the Americas of WHO
# 854       8632  Argentina  Region of the Americas of WHO
#
#                    FLUREGION  Year  Week       SDATE       EDATE  \
# 849  Temperate South America  2009    13  2009-03-23  2009-03-29
# 850  Temperate South America  2009    14  2009-03-30  2009-04-05
# 851  Temperate South America  2009    15  2009-04-06  2009-04-12
# 852  Temperate South America  2009    16  2009-04-13  2009-04-19
# 854  Temperate South America  2009    18  2009-04-27  2009-05-03
#
#      SPEC_RECEIVED_NB  SPEC_PROCESSED_NB  ...  INF_A  BYAMAGATA  BVICTORIA  \
# 849               1.0                1.0  ...      0        0.0        0.0
# 850               1.0                1.0  ...      0        0.0        0.0
# ...

# %%
heatmap.generate_heat_map(df, country_column='Country', count_column='Initial_Infected')
# Out:
# c:\Users\muhta\Downloads\HealthAnalytics\heatmap.py:14: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
mystatistics.calculate_incidence_rate(df, count_column='Initial_Infected', population_column='Population')
# Out:
#        REPORT_ID    Country                      WHOREGION  \
# 849         8627  Argentina  Region of the Americas of WHO
# 850         8628  Argentina  Region of the Americas of WHO
# 851         8629  Argentina  Region of the Americas of WHO
# 852         8630  Argentina  Region of the Americas of WHO
# 854         8632  Argentina  Region of the Americas of WHO
# ...          ...        ...                            ...
# 37538     219257     Zambia          African Region of WHO
# 37539     219258     Zambia          African Region of WHO
# 37540     219259     Zambia          African Region of WHO
# 37541     219260     Zambia          African Region of WHO
# 37542     219261     Zambia          African Region of WHO
#
#                      FLUREGION  Year  Week       SDATE       EDATE  \
# 849    Temperate South America  2009    13  2009-03-23  2009-03-29
# 850    Temperate South America  2009    14  2009-03-30  2009-04-05
# ...

# %%
advanced_clustering.advanced_dbscan_clustering(df)
# Out:
# DBSCAN()

# %%
import vaccine

# %%
df = vaccine.add_vaccine(df, infected_column='Initial_Infected')

# %%
df.head()
# Out:
#      REPORT_ID    Country                      WHOREGION  \
# 849       8627  Argentina  Region of the Americas of WHO
# 850       8628  Argentina  Region of the Americas of WHO
# 851       8629  Argentina  Region of the Americas of WHO
# 852       8630  Argentina  Region of the Americas of WHO
# 854       8632  Argentina  Region of the Americas of WHO
#
#                    FLUREGION  Year  Week       SDATE       EDATE  \
# 849  Temperate South America  2009    13  2009-03-23  2009-03-29
# 850  Temperate South America  2009    14  2009-03-30  2009-04-05
# 851  Temperate South America  2009    15  2009-04-06  2009-04-12
# 852  Temperate South America  2009    16  2009-04-13  2009-04-19
# 854  Temperate South America  2009    18  2009-04-27  2009-05-03
#
#      SPEC_RECEIVED_NB  SPEC_PROCESSED_NB  ...  BNOTDETERMINED  INF_B  ALL_INF  \
# 849               1.0                1.0  ...             0.0      0        0
# ...

# %%
heatmap.generate_vaccine_based_heat_map(df, location_column='Country',
                                        vaccines_required_column='Initial_Infected', vaccines_supplied_column='vaccines_supplied')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 heatmap.generate_vaccine_based_heat_map(df, location_column='Country',
#       2                                         vaccines_required_column='Initial_Infected', vaccines_supplied_column='vaccines_supplied')
#
# TypeError: generate_vaccine_based_heat_map() missing 1 required positional argument: 'geo_data'
